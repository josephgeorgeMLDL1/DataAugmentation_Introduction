# %% [markdown]
# <a href="https://colab.research.google.com/github/josephgeorgeMLDL1/DataAugmentation_Introduction/blob/main/1_Data_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Data Augmentation
# https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image_path='/content/drive/MyDrive/DeepLearning/6--Augmentation_Introduction/cat3.jpg'

# %% [markdown]
# ### Load libraries and image data

# %%
# Importing the required libraries
from numpy import expand_dims

from keras.utils import load_img
from keras.utils import img_to_array

from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
# Loading desired images
img = load_img(image_path)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x316 at 0x7F35264D2340>

# %%
# For processing, we are converting the image(s) to an array
data = img_to_array(img)

# %%
data
# Out:
# array([[[192., 201., 144.],
#         [183., 192., 135.],
#         [168., 182., 121.],
#         ...,
#         [154., 153., 151.],
#         [159., 158., 156.],
#         [159., 158., 156.]],
#
#        [[183., 193., 132.],
#         [176., 188., 126.],
#         [165., 180., 115.],
#         ...,
#         [153., 152., 150.],
#         [158., 157., 155.],
#         [158., 157., 155.]],
#
#        [[171., 184., 115.],
#         [164., 179., 110.],
#         [154., 171., 100.],
#         ...,
#         [152., 151., 149.],
#         [157., 156., 154.],
#         [157., 156., 154.]],
#
#        ...,
#
#        [[ 27.,  27.,  27.],
#         [  3.,   3.,   3.],
#         [ 12.,  12.,  12.],
#         ...,
#         [224., 232., 245.],
#         [232., 240., 253.],
#         [230., 238., 251.]],
#
#        [[ 50.,  50.,  50.],
#         [ 15.,  15.,  15.],
#         [ 12.,  12.,  12.],
#         ...,
#         [224., 232., 245.],
#         [228., 236., 249.],
#         [225., 233., 246.]],
#
#        [[ 63.,  63.,  63.],
#         [ 19.,  19.,  19.],
#         [ 10.,  10.,  10.],
#         ...,
#         [224., 230., 244.],
#         [226., 232., 246.],
#         [224., 230., 244.]]], dtype=float32)

# %%
data.shape
# Out:
# (316, 474, 3)

# %%
#data.reshape(299,299,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-1c06735b7606> in <module>
# ----> 1 data.reshape(299,299,3)
#
# ValueError: cannot reshape array of size 449352 into shape (299,299,3)

# %%
# Expanding dimension to one sample (Add the image to a batch)
samples = expand_dims(data, 0)

# %%
print(type(img))
print(type(data))
print(type(samples))
print(samples.shape)
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (1, 316, 474, 3)

# %% [markdown]
# ### Function to plot and save

# %%
def plotSave(itr, filePath='augment.png'):

  # Preparing the Samples and Plot for displaying output
  for i in range(9):

    # preparing the subplot
    plt.subplot(3,3, i+1)


    # generating images in batches  
    batch = itr.next()

    # Remember to convert these images to unsigned integers for viewing 
    image = batch[0].astype('uint8')

    # Plot and save the data
    plt.axis('off')
    plt.imshow(image)
    plt.savefig(filePath, dpi=300)

  plt.show()

# %% [markdown]
# ### Rotation
#
# https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator

# %%
# Calling ImageDataGenerator for creating data augmentation generator.
datagen = ImageDataGenerator(rotation_range=45)

# Creating an iterator for data augmentation
itr = datagen.flow(samples, batch_size=1)

plotSave(itr, '/content/drive/MyDrive/DeepLearning/6--Augmentation_Introduction/01_Rotation.png')

# %% [markdown]
# ### Width shift

# %%
# Calling ImageDataGenerator for creating data augmentation generator.
datagen = ImageDataGenerator(width_shift_range=[-30,30])

# Creating an iterator for data augmentation
itr = datagen.flow(samples, batch_size=1)

plotSave(itr, '/content/drive/MyDrive/DeepLearning/6--Augmentation_Introduction/02_RandomShift_Width.png')

# %% [markdown]
# ### Height shift

# %%
# Calling ImageDataGenerator for creating data augmentation generator.
datagen = ImageDataGenerator(height_shift_range=[-50,50])

# Creating an iterator for data augmentation
itr = datagen.flow(samples, batch_size=1)

plotSave(itr, '/content/drive/MyDrive/DeepLearning/6--Augmentation_Introduction/03_RandomShift_Height.png')

# %% [markdown]
# ## Random Flipping
# ### Horizontal flip

# %%
# Calling ImageDataGenerator for creating data augmentation generator.
datagen = ImageDataGenerator(horizontal_flip=True)

# Creating an iterator for data augmentation
itr = datagen.flow(samples, batch_size=1)

plotSave(itr, '/content/drive/MyDrive/DeepLearning/6--Augmentation_Introduction/04_Flip_Horizontal.png')

# %% [markdown]
# ### Vertical flip

# %%
# Calling ImageDataGenerator for creating data augmentation generator.
datagen = ImageDataGenerator(vertical_flip=True)

# Creating an iterator for data augmentation
itr = datagen.flow(samples, batch_size=1)

plotSave(itr, '/content/drive/MyDrive/DeepLearning/6--Augmentation_Introduction/05_Flip_Vertical.png')
